# %%
# !pip install botorch ax-platform ioh
# Out:
# Collecting botorch
#   Downloading botorch-0.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting ax-platform
#   Downloading ax_platform-0.4.3-py3-none-any.whl.metadata (11 kB)
# Collecting ioh
#   Downloading ioh-0.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from botorch) (1.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from botorch) (1.13.1)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.10/dist-packages (from botorch) (1.3.0)
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from botorch) (2.5.1+cu121)
# Collecting pyro-ppl>=1.8.4 (from botorch)
#   Downloading pyro_ppl-1.9.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from botorch) (4.12.2)
# Collecting gpytorch==1.13 (from botorch)
#   Downloading gpytorch-1.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting linear-operator==0.5.3 (from botorch)
#   Downloading linear_operator-0.5.3-py3-none-any.whl.metadata (15 kB)
# Collecting jaxtyping==0.2.19 (from gpytorch==1.13->botorch)
#   Downloading jaxtyping-0.2.19-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from gpytorch==1.13->botorch) (1.6.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from jaxtyping==0.2.19->gpytorch==1.13->botorch) (1.26.4)
# Requirement already satisfied: typeguard>=2.13.3 in /usr/local/lib/python3.10/dist-packages (from jaxtyping==0.2.19->gpytorch==1.13->botorch) (4.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from ax-platform) (3.1.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ax-platform) (2.2.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from ax-platform) (7.7.1)
# Requirement already satisfied: plotly>=5.12.0 in /usr/local/lib/python3.10/dist-packages (from ax-platform) (5.24.1)
# Collecting pyre-extensions (from ax-platform)
#   Downloading pyre_extensions-0.0.32-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.12.0->ax-platform) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.12.0->ax-platform) (24.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl>=1.8.4->botorch) (3.4.0)
# Collecting pyro-api>=0.1.1 (from pyro-ppl>=1.8.4->botorch)
#   Downloading pyro_api-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl>=1.8.4->botorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->botorch) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->botorch) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->botorch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->botorch) (1.13.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ax-platform) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ax-platform) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ax-platform) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ax-platform) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->ax-platform) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->ax-platform) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ax-platform) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ax-platform) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ax-platform) (2024.2)
# Collecting typing-inspect (from pyre-extensions->ax-platform)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gpytorch==1.13->botorch) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->gpytorch==1.13->botorch) (3.5.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->ax-platform) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->ax-platform)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->ax-platform) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->ax-platform) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.5.5)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect->pyre-extensions->ax-platform)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ax-platform) (0.8.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (7.16.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->ax-platform) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ax-platform) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.10.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (0.22.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ax-platform) (1.2.2)
# Downloading botorch-0.12.0-py3-none-any.whl (644 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 21.3 MB/s eta 0:00:00
# Downloading gpytorch-1.13-py3-none-any.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.8/277.8 kB 22.5 MB/s eta 0:00:00
# Downloading linear_operator-0.5.3-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 16.5 MB/s eta 0:00:00
# Downloading jaxtyping-0.2.19-py3-none-any.whl (24 kB)
# Downloading ax_platform-0.4.3-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.7 MB/s eta 0:00:00
# Downloading ioh-0.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 13.2 MB/s eta 0:00:00
# Downloading pyro_ppl-1.9.1-py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 45.8 MB/s eta 0:00:00
# Downloading pyre_extensions-0.0.32-py3-none-any.whl (12 kB)
# Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.6 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: pyro-api, mypy-extensions, jedi, ioh, typing-inspect, jaxtyping, pyro-ppl, pyre-extensions, linear-operator, gpytorch, botorch, ax-platform
# Successfully installed ax-platform-0.4.3 botorch-0.12.0 gpytorch-1.13 ioh-0.3.18 jaxtyping-0.2.19 jedi-0.19.2 linear-operator-0.5.3 mypy-extensions-1.0.0 pyre-extensions-0.0.32 pyro-api-0.1.2 pyro-ppl-1.9.1 typing-inspect-0.9.0

# %%
import numpy as np
import ioh
import math
import torch

from gpytorch.kernels import RBFKernel
from gpytorch.constraints import GreaterThan
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.priors import LogNormalPrior
from botorch.models.transforms import Normalize, Standardize
from botorch.models import SingleTaskGP
from botorch.acquisition import LogExpectedImprovement

from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy
from ax.modelbridge.registry import Models
from ax.models.torch.botorch_modular.surrogate import Surrogate
from ax.models.torch.botorch_modular.model import BoTorchModel
from ax.service.utils.instantiation import ObjectiveProperties
from ax.service.ax_client import AxClient
# Out:
# [WARNING 12-30 01:28:47] ax.service.utils.with_db_settings_base: Ax currently requires a sqlalchemy version below 2.0. This will be addressed in a future release. Disabling SQL storage in Ax for now, if you would like to use SQL storage please install Ax with mysql extras via `pip install ax-platform[mysql]`.

# %%
class Rembo():

    def __init__(self, lc_prior, pb_id, dim, embedding_dim, problem, root):
        self.debug = False #debug print statement
        self.prior_mean = lc_prior
        self.unwrapped_pb = problem
        self.dim = dim
        self.embedding_dim = embedding_dim
        self.pb_id = pb_id

        self.l = ioh.logger.Analyzer(root=root, folder_name="vanilla_f"+str(pb_id)+"_"+str(dim)+"d", algorithm_name="rembo")
        self.unwrapped_pb.attach_logger(self.l)



    def reset_problem(self):
        self.unwrapped_pb.reset()

    def apply_embedding(self, x):
        x = np.array(list(x.values()))

        x = self.transform_matrix @ x.transpose()

        for i in range(x.shape[0]):
            if x[i] < self.unwrapped_pb.bounds.lb[i]:
                x[i] = self.unwrapped_pb.bounds.lb[i]
            elif x[i] > self.unwrapped_pb.bounds.ub[i]:
                x[i] = self.unwrapped_pb.bounds.ub[i]

        return {"f"+str(self.pb_id):(self.unwrapped_pb(x), 0)}

    def calc_objective(self):
        #the x value will be wrong but the y should allow logger to properly log progress
        return ([0 for x in range(self.dim)], self.unwrapped_pb.optimum.y)


    def run(self):
        self.transform_matrix = np.random.normal(0, 1, (self.dim, self.embedding_dim))

        #covar = RBFKernel(ard_num_dims=self.embedding_dim, lengthscale_prior=LogNormalPrior(self.prior_mean, math.sqrt(3)), lengthscale_constraint=GreaterThan(1e-4))

        gs = GenerationStrategy(
            steps=[
                # Quasi-random initialization step
                GenerationStep(
                    model=Models.SOBOL,
                    num_trials=self.dim,  # How many trials should be produced from this generation step
                ),
                # Bayesian optimization step using the custom acquisition function
                GenerationStep(
                    model=Models.BOTORCH_MODULAR,
                    num_trials=9*self.dim,
                    # For `BOTORCH_MODULAR`, we pass in kwargs to specify what surrogate or acquisition function to use.
                    model_kwargs={
                        "surrogate": Surrogate(botorch_model_class=SingleTaskGP, covar_module_class=RBFKernel, covar_module_options=dict(ard_num_dims=self.embedding_dim, lengthscale_prior=LogNormalPrior(self.prior_mean, math.sqrt(3)), lengthscale_constraint=GreaterThan(1e-4))),"botorch_acqf_class":LogExpectedImprovement
                    },
                ),
            ]
        )

        ax_client = AxClient(generation_strategy=gs)

        params = [{"name":"x"+str(i),"type":"range","bounds":[-math.sqrt(self.embedding_dim),math.sqrt(self.embedding_dim)]} for i in range(self.embedding_dim)]

        ax_client.create_experiment(
            name="f"+str(self.pb_id)+"_experiment",
            parameters=params,
            objectives={
                "f"+str(self.pb_id): ObjectiveProperties(minimize=True),
            },
        )

        for i in range(10*self.dim):
            parameters, trial_index = ax_client.get_next_trial()
            if self.debug:
                print(trial_index)
            ax_client.complete_trial(trial_index=trial_index, raw_data=self.apply_embedding(parameters))


        parameters, values = ax_client.get_best_parameters()
        print(f"Best parameters: {parameters}")
        print(f"Corresponding mean: {values[0]}, covariance: {values[1]}")

# %%
torch.manual_seed(0)

dim=40
pb_id=8
root="./data"
problem = ioh.get_problem(pb_id, dimension=dim, instance=1, problem_class=ioh.ProblemClass.BBOB)

model = Rembo(1, pb_id, dim, int(dim/4), problem, root)

for i in range(5):
    print(i)
    model.run()

    model.reset_problem()
# Out:
# [INFO 12-30 05:57:15] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x0. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x1. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x2. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x3. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x4. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x5. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x6. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x7. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x8. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter x9. If that is not the expected value type, you can explicitly specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 12-30 05:57:15] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='x0', parameter_type=FLOAT, range=[-3.1622776601683795, 3.1622776601683795]), RangeParameter(name='x1', parameter_type=FLOAT, range=[-3.1622776601683795, 3.1622776601683795]), RangeParameter(name='x2', parameter_type=FLOAT, range=[-3.1622776601683795, 3.1622776601683795]), RangeParameter(name='x3', parameter_type=FLOAT, range=[-3.1622776601683795, 3.1622776601683795]), RangeParameter(name='x4', parameter_type=FLOAT, range=[-3.1622776601683795, 3.1622776601683795]), RangeParameter(name='x5', parameter_type=FLOAT, range=[-3.1622776601683795, 3.1622776601683795]), RangeParameter(name='x6', parameter_type=FLOAT, range=[-3.1622776601683795, 3.1622776601683795]), RangeParameter(name='x7', parameter_type=FLOAT, range=[-3.1622776601683795, 3.1622776601683795]), RangeParameter(name='x8', parameter_type=FLOAT, range=[-3.1622776601683795, 3.1622776601683795]), RangeParameter(name='x9', parameter_type=FLOAT, range=[-3.1622776601683795, 3.1622776601683795])], parameter_constraints=[]).
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:15] ax.service.ax_client: Generated new trial 0 with parameters {'x0': -0.79022, 'x1': 2.892246, 'x2': -0.765505, 'x3': 0.350305, 'x4': 2.956676, 'x5': 2.211446, 'x6': 0.734811, 'x7': 0.099835, 'x8': -0.256045, 'x9': 0.588999} using model Sobol.
# [INFO 12-30 05:57:15] ax.service.ax_client: Completed trial 0 with data: {'f8': (2821915.084234, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:15] ax.service.ax_client: Generated new trial 1 with parameters {'x0': 1.510422, 'x1': -2.487413, 'x2': 2.983796, 'x3': -1.390796, 'x4': -0.839423, 'x5': -1.557824, 'x6': -0.263197, 'x7': -1.180155, 'x8': 2.376042, 'x9': -1.666844} using model Sobol.
# [INFO 12-30 05:57:15] ax.service.ax_client: Completed trial 1 with data: {'f8': (1462605.356852, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:15] ax.service.ax_client: Generated new trial 2 with parameters {'x0': 2.311259, 'x1': 0.244425, 'x2': -2.143548, 'x3': 2.916708, 'x4': -2.421922, 'x5': -2.035471, 'x6': 1.722016, 'x7': -2.818146, 'x8': 0.958483, 'x9': -0.767935} using model Sobol.
# [INFO 12-30 05:57:15] ax.service.ax_client: Completed trial 2 with data: {'f8': (2288271.668589, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:15] ax.service.ax_client: Generated new trial 3 with parameters {'x0': -3.145561, 'x1': -0.601789, 'x2': 1.209887, 'x3': -1.591278, 'x4': 1.293933, 'x5': 1.307732, 'x6': -2.04231, 'x7': 2.22005, 'x8': -1.895573, 'x9': 1.870863} using model Sobol.
# [INFO 12-30 05:57:15] ax.service.ax_client: Completed trial 3 with data: {'f8': (4332385.565154, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:15] ax.service.ax_client: Generated new trial 4 with parameters {'x0': -2.315626, 'x1': 0.910237, 'x2': 2.014094, 'x3': -3.064643, 'x4': 0.031112, 'x5': 2.453735, 'x6': 2.67887, 'x7': -1.905276, 'x8': 0.666832, 'x9': -3.009469} using model Sobol.
# [INFO 12-30 05:57:15] ax.service.ax_client: Completed trial 4 with data: {'f8': (2677464.406347, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 5 with parameters {'x0': 3.14737, 'x1': -1.319328, 'x2': -1.37699, 'x3': 1.838424, 'x4': -2.151469, 'x5': -0.144834, 'x6': -3.050299, 'x7': 2.54008, 'x8': -2.780512, 'x9': 1.124072} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 5 with data: {'f8': (3597520.433294, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 6 with parameters {'x0': 0.785467, 'x1': 2.178422, 'x2': 0.635568, 'x3': -0.103357, 'x4': -0.516465, 'x5': -2.586477, 'x6': 1.294244, 'x7': 1.458221, 'x8': -1.344418, 'x9': 2.7935} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 6 with data: {'f8': (2187463.961234, 0)}.
# 0
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 7 with parameters {'x0': -1.508999, 'x1': -1.817596, 'x2': -3.150223, 'x3': 1.24228, 'x4': 1.647539, 'x5': 0.351691, 'x6': -0.876493, 'x7': -0.414609, 'x8': 2.275473, 'x9': -0.932426} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 7 with data: {'f8': (1787603.278912, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 8 with parameters {'x0': -0.933274, 'x1': 0.789947, 'x2': 0.343894, 'x3': 2.254765, 'x4': -1.515207, 'x5': 0.95381, 'x6': 3.115347, 'x7': -2.075668, 'x8': 0.160132, 'x9': 2.370943} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 8 with data: {'f8': (2968912.447476, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 9 with parameters {'x0': 0.175434, 'x1': -0.352689, 'x2': -2.663703, 'x3': -2.696202, 'x4': 2.643799, 'x5': -1.583331, 'x6': -2.594129, 'x7': 3.157072, 'x8': -2.669193, 'x9': -0.280184} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 9 with data: {'f8': (3244521.548403, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 10 with parameters {'x0': 2.562333, 'x1': 2.447047, 'x2': 1.725221, 'x3': 0.874582, 'x4': 1.011479, 'x5': -1.123613, 'x6': 0.940756, 'x7': 0.842772, 'x8': -1.060548, 'x9': -2.154975} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 10 with data: {'f8': (2140867.343461, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 11 with parameters {'x0': -1.714713, 'x1': -2.833748, 'x2': -0.887672, 'x3': -0.518884, 'x4': -3.128949, 'x5': 1.87666, 'x6': -1.211833, 'x7': -0.242673, 'x8': 1.596222, 'x9': 0.088538} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 11 with data: {'f8': (3206295.46775, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 12 with parameters {'x0': -2.557001, 'x1': 1.931686, 'x2': -1.64458, 'x3': -1.022723, 'x4': -1.870961, 'x5': 0.698809, 'x6': 0.390007, 'x7': 0.718011, 'x8': -0.564717, 'x9': -1.235245} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 12 with data: {'f8': (3346165.139174, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 13 with parameters {'x0': 1.713869, 'x1': -2.36085, 'x2': 0.905959, 'x3': 0.766235, 'x4': 0.739284, 'x5': -3.032971, 'x6': -0.613014, 'x7': -1.35554, 'x8': 3.079902, 'x9': 2.503012} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 13 with data: {'f8': (1339942.639299, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 14 with parameters {'x0': 0.937448, 'x1': 1.254304, 'x2': -0.26393, 'x3': -2.007998, 'x4': 2.325288, 'x5': -0.584594, 'x6': 2.168337, 'x7': -2.644305, 'x8': 1.440381, 'x9': 1.414181} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 14 with data: {'f8': (2427214.684987, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 15 with parameters {'x0': -0.177437, 'x1': -0.876493, 'x2': 2.682472, 'x3': 2.547867, 'x4': -0.204714, 'x5': 2.795229, 'x6': -1.602546, 'x7': 1.60033, 'x8': -1.982283, 'x9': -2.707031} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 15 with data: {'f8': (3351560.055854, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 16 with parameters {'x0': -0.360235, 'x1': 1.412224, 'x2': -2.447818, 'x3': -0.289851, 'x4': 1.505209, 'x5': -2.803387, 'x6': -0.075912, 'x7': -2.455096, 'x8': -2.490405, 'x9': 0.948272} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 16 with data: {'f8': (2305860.376014, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 17 with parameters {'x0': 1.094328, 'x1': -1.002759, 'x2': 0.128003, 'x3': 1.528371, 'x4': -2.636763, 'x5': 0.591786, 'x6': 0.495258, 'x7': 1.795609, 'x8': 0.364038, 'x9': -2.836235} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 17 with data: {'f8': (2353052.99225, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 18 with parameters {'x0': 1.89972, 'x1': 1.725949, 'x2': -1.066493, 'x3': -2.855952, 'x4': -1.01995, 'x5': 3.028866, 'x6': -2.251215, 'x7': 0.530452, 'x8': 1.78758, 'x9': -1.151896} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 18 with data: {'f8': (2496437.288519, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 19 with parameters {'x0': -2.72322, 'x1': -2.084857, 'x2': 1.904036, 'x3': 1.729324, 'x4': 3.140599, 'x5': -0.693739, 'x6': 1.878193, 'x7': -1.549382, 'x8': -0.844121, 'x9': 3.015518} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 19 with data: {'f8': (3444860.317458, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 20 with parameters {'x0': -1.897911, 'x1': 2.590997, 'x2': 1.097717, 'x3': 3.004284, 'x4': 1.828466, 'x5': -1.869466, 'x6': -2.835174, 'x7': 1.048848, 'x8': 2.876338, 'x9': -1.788622} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 20 with data: {'f8': (2440121.401936, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 21 with parameters {'x0': 2.718852, 'x1': -2.998544, 'x2': -1.836345, 'x3': -1.976094, 'x4': -0.699992, 'x5': 1.115454, 'x6': 2.516374, 'x7': -0.042667, 'x8': -0.743937, 'x9': 0.711305} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 21 with data: {'f8': (2766024.457946, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 22 with parameters {'x0': 0.361658, 'x1': 0.496173, 'x2': 2.478366, 'x3': 0.042503, 'x4': -2.363121, 'x5': 1.588399, 'x6': -1.057652, 'x7': -2.283394, 'x8': -2.198367, 'x9': 1.597329} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 22 with data: {'f8': (3696975.703014, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 23 with parameters {'x0': -1.099081, 'x1': -0.139979, 'x2': -0.05983, 'x3': -1.380228, 'x4': 0.245581, 'x5': -0.957914, 'x6': 1.527771, 'x7': 2.955629, 'x8': 1.24859, 'x9': -0.494936} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 23 with data: {'f8': (1775546.709058, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 24 with parameters {'x0': -1.301476, 'x1': 2.069239, 'x2': 2.767338, 'x3': -2.342628, 'x4': -2.917202, 'x5': -0.355313, 'x6': -2.389184, 'x7': 1.270677, 'x8': 2.592083, 'x9': 2.725059} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 24 with data: {'f8': (3269197.100157, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 25 with parameters {'x0': 0.554451, 'x1': -1.64279, 'x2': -0.549053, 'x3': 2.586809, 'x4': 0.797109, 'x5': 2.592221, 'x6': 2.956567, 'x7': -0.608416, 'x8': -0.064301, 'x9': -1.454732} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 25 with data: {'f8': (3212236.83257, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 26 with parameters {'x0': 2.936833, 'x1': 1.166252, 'x2': 1.389293, 'x3': -0.961974, 'x4': 2.46297, 'x5': 0.136, 'x6': -1.401339, 'x7': -1.716101, 'x8': -1.692054, 'x9': -2.533766} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 26 with data: {'f8': (2394821.592676, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 27 with parameters {'x0': -2.075311, 'x1': -1.545234, 'x2': -2.32296, 'x3': 0.409792, 'x4': -1.331585, 'x5': -2.447025, 'x6': 1.176743, 'x7': 2.735345, 'x8': 1.137658, 'x9': 1.238362} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 27 with data: {'f8': (2790467.914755, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:16] ax.service.ax_client: Generated new trial 28 with parameters {'x0': -2.937678, 'x1': 0.050197, 'x2': -1.568164, 'x3': 1.110487, 'x4': -0.024282, 'x5': -1.301986, 'x6': -0.42983, 'x7': -3.025887, 'x8': -2.971916, 'x9': -0.007203} using model Sobol.
# [INFO 12-30 05:57:16] ax.service.ax_client: Completed trial 28 with data: {'f8': (2836220.416987, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 29 with parameters {'x0': 2.080643, 'x1': -0.487081, 'x2': 2.205262, 'x3': -0.656743, 'x4': 2.141267, 'x5': 2.031848, 'x6': 0.160249, 'x7': 2.018572, 'x8': 0.450361, 'x9': 2.097441} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 29 with data: {'f8': (2162325.17512, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 30 with parameters {'x0': 1.299474, 'x1': 3.137284, 'x2': -2.946691, 'x3': 2.095485, 'x4': 0.52791, 'x5': 1.564533, 'x6': -1.813526, 'x7': 0.305945, 'x8': 2.096637, 'x9': 0.210827} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 30 with data: {'f8': (2543043.559895, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 31 with parameters {'x0': -0.550277, 'x1': -2.748664, 'x2': 0.43203, 'x3': -2.43887, 'x4': -1.656215, 'x5': -2.220278, 'x6': 2.333247, 'x7': -0.980135, 'x8': -1.548367, 'x9': -2.276724} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 31 with data: {'f8': (2641166.538768, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 32 with parameters {'x0': -0.461053, 'x1': 0.360729, 'x2': 1.652057, 'x3': -1.191627, 'x4': 1.748715, 'x5': -2.523198, 'x6': -2.286314, 'x7': -0.789196, 'x8': 0.294548, 'x9': 0.639794} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 32 with data: {'f8': (1561357.376522, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 33 with parameters {'x0': 1.197256, 'x1': -0.769627, 'x2': -0.9114, 'x3': 0.157266, 'x4': -0.410707, 'x5': 0.01669, 'x6': 1.867018, 'x7': 1.290822, 'x8': -2.411651, 'x9': -1.909545} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 33 with data: {'f8': (2357023.553628, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 34 with parameters {'x0': 1.997317, 'x1': 2.826902, 'x2': 0.268803, 'x3': -1.781232, 'x4': -2.061122, 'x5': 2.711532, 'x6': -0.111832, 'x7': 2.616571, 'x8': -0.975374, 'x9': -0.423813} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 34 with data: {'f8': (3623884.101001, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 35 with parameters {'x0': -2.817161, 'x1': -2.466269, 'x2': -2.689361, 'x3': 3.125139, 'x4': 0.129134, 'x5': -0.27914, 'x6': 0.484806, 'x7': -1.634336, 'x8': 1.903392, 'x9': 1.717863} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 35 with data: {'f8': (2906180.732405, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 36 with parameters {'x0': -1.999561, 'x1': 2.354729, 'x2': -0.337069, 'x3': 1.633102, 'x4': 1.189672, 'x5': -2.29638, 'x6': -1.120593, 'x7': 2.146805, 'x8': -0.67446, 'x9': -2.961786} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 36 with data: {'f8': (2586150.440926, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 37 with parameters {'x0': 2.821093, 'x1': -1.950089, 'x2': 2.65872, 'x3': -2.877805, 'x4': -2.530766, 'x5': 1.445103, 'x6': 1.439343, 'x7': -3.092402, 'x8': 2.797596, 'x9': 0.872131} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 37 with data: {'f8': (2618603.671367, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 38 with parameters {'x0': 0.459967, 'x1': 0.880624, 'x2': -1.719648, 'x3': 1.438386, 'x4': -0.926668, 'x5': 2.15128, 'x6': -2.898837, 'x7': -0.814991, 'x8': 1.379831, 'x9': 3.140686} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 38 with data: {'f8': (3012911.761819, 0)}.
# /usr/local/lib/python3.10/dist-packages/ax/modelbridge/cross_validation.py:463: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 12-30 05:57:17] ax.service.ax_client: Generated new trial 39 with parameters {'x0': -1.192166, 'x1': -1.237796, 'x2': 0.880276, 'x3': -0.305587, 'x4': 2.861758, 'x5': -1.225887, 'x6': 2.428768, 'x7': 0.276727, 'x8': -2.314167, 'x9': -1.076137} using model Sobol.
# [INFO 12-30 05:57:17] ax.service.ax_client: Completed trial 39 with data: {'f8': (2514613.194023, 0)}.
# [INFO 12-30 05:57:19] ax.service.ax_client: Generated new trial 40 with parameters {'x0': 1.195006, 'x1': -0.761268, 'x2': 0.967413, 'x3': -1.091817, 'x4': 1.720758, 'x5': -2.123703, 'x6': -0.848058, 'x7': -0.018377, 'x8': 2.209765, 'x9': -0.938214} using model BoTorch.
# [INFO 12-30 05:57:19] ax.service.ax_client: Completed trial 40 with data: {'f8': (1614173.241458, 0)}.
# [INFO 12-30 05:57:21] ax.service.ax_client: Generated new trial 41 with parameters {'x0': 0.788521, 'x1': -2.639312, 'x2': 1.908557, 'x3': -0.086925, 'x4': 0.497679, 'x5': -2.139593, 'x6': -0.822713, 'x7': -0.722674, 'x8': 1.764181, 'x9': 0.44224} using model BoTorch.
# [INFO 12-30 05:57:21] ax.service.ax_client: Completed trial 41 with data: {'f8': (1264333.823205, 0)}.
# [INFO 12-30 05:57:22] ax.service.ax_client: Generated new trial 42 with parameters {'x0': 0.724486, 'x1': -2.517491, 'x2': 2.245874, 'x3': 0.173854, 'x4': 0.82107, 'x5': -2.565434, 'x6': -1.818259, 'x7': -2.719291, 'x8': 1.937315, 'x9': 1.476016} using model BoTorch.
# [INFO 12-30 05:57:22] ax.service.ax_client: Completed trial 42 with data: {'f8': (1936161.026055, 0)}.
# [INFO 12-30 05:57:24] ax.service.ax_client: Generated new trial 43 with parameters {'x0': 1.006612, 'x1': -3.162278, 'x2': -2.020812, 'x3': 0.806267, 'x4': 0.68761, 'x5': -1.981611, 'x6': -1.176259, 'x7': -1.077121, 'x8': 2.510723, 'x9': -0.084919} using model BoTorch.
# [INFO 12-30 05:57:24] ax.service.ax_client: Completed trial 43 with data: {'f8': (1441154.605078, 0)}.
# [INFO 12-30 05:57:26] ax.service.ax_client: Generated new trial 44 with parameters {'x0': 1.8799, 'x1': -3.162278, 'x2': 3.162278, 'x3': -0.263267, 'x4': 0.176117, 'x5': -1.703813, 'x6': 0.050558, 'x7': -0.523128, 'x8': 2.877709, 'x9': 2.070824} using model BoTorch.
# [INFO 12-30 05:57:26] ax.service.ax_client: Completed trial 44 with data: {'f8': (1630814.777864, 0)}.
# [INFO 12-30 05:57:28] ax.service.ax_client: Generated new trial 45 with parameters {'x0': 0.968264, 'x1': -1.486521, 'x2': 3.162278, 'x3': 0.698853, 'x4': 0.031099, 'x5': -3.162278, 'x6': -0.910945, 'x7': -1.161149, 'x8': 1.591217, 'x9': 0.371399} using model BoTorch.
# [INFO 12-30 05:57:28] ax.service.ax_client: Completed trial 45 with data: {'f8': (1313113.190928, 0)}.
# [INFO 12-30 05:57:30] ax.service.ax_client: Generated new trial 46 with parameters {'x0': 0.488361, 'x1': -2.751264, 'x2': 1.486155, 'x3': -3.162278, 'x4': 0.788584, 'x5': -2.901218, 'x6': -0.837356, 'x7': -1.214512, 'x8': 1.943366, 'x9': 1.154799} using model BoTorch.
# [INFO 12-30 05:57:30] ax.service.ax_client: Completed trial 46 with data: {'f8': (2627397.409272, 0)}.
# [INFO 12-30 05:57:32] ax.service.ax_client: Generated new trial 47 with parameters {'x0': 0.329223, 'x1': -0.077385, 'x2': 1.273438, 'x3': -0.119116, 'x4': 0.377054, 'x5': -1.881672, 'x6': 0.682426, 'x7': 0.561241, 'x8': 1.587712, 'x9': -0.67515} using model BoTorch.
# [INFO 12-30 05:57:32] ax.service.ax_client: Completed trial 47 with data: {'f8': (662497.936196, 0)}.
# [INFO 12-30 05:57:34] ax.service.ax_client: Generated new trial 48 with parameters {'x0': 0.269892, 'x1': 0.518536, 'x2': 0.638758, 'x3': 0.109297, 'x4': 0.023923, 'x5': -1.910975, 'x6': 2.733838, 'x7': 0.383336, 'x8': 2.525707, 'x9': -0.642025} using model BoTorch.
# [INFO 12-30 05:57:34] ax.service.ax_client: Completed trial 48 with data: {'f8': (1316648.103105, 0)}.
# [INFO 12-30 05:57:36] ax.service.ax_client: Generated new trial 49 with parameters {'x0': 0.606667, 'x1': -0.027523, 'x2': 0.298178, 'x3': 0.094749, 'x4': 0.002363, 'x5': -1.814253, 'x6': 0.194486, 'x7': 0.028447, 'x8': 1.754554, 'x9': -1.35151} using model BoTorch.
# [INFO 12-30 05:57:36] ax.service.ax_client: Completed trial 49 with data: {'f8': (875931.723901, 0)}.
# [INFO 12-30 05:57:38] ax.service.ax_client: Generated new trial 50 with parameters {'x0': 0.401307, 'x1': 0.097547, 'x2': 1.947961, 'x3': 0.487601, 'x4': 0.896942, 'x5': -2.301592, 'x6': 0.456445, 'x7': 1.162769, 'x8': 1.639642, 'x9': 0.581893} using model BoTorch.
# [INFO 12-30 05:57:38] ax.service.ax_client: Completed trial 50 with data: {'f8': (708781.136905, 0)}.
# [INFO 12-30 05:57:39] ax.service.ax_client: Generated new trial 51 with parameters {'x0': 0.234943, 'x1': -0.095954, 'x2': 3.162278, 'x3': -0.211947, 'x4': 0.457136, 'x5': -2.208246, 'x6': 0.893295, 'x7': 0.713021, 'x8': 1.126272, 'x9': -0.952472} using model BoTorch.
# [INFO 12-30 05:57:39] ax.service.ax_client: Completed trial 51 with data: {'f8': (1279659.989335, 0)}.
# [INFO 12-30 05:57:42] ax.service.ax_client: Generated new trial 52 with parameters {'x0': 1.625286, 'x1': -0.271477, 'x2': 1.559931, 'x3': 0.767708, 'x4': -0.467976, 'x5': -2.768293, 'x6': 0.824291, 'x7': 0.904896, 'x8': 1.969662, 'x9': -1.906063} using model BoTorch.
# [INFO 12-30 05:57:42] ax.service.ax_client: Completed trial 52 with data: {'f8': (1313941.558509, 0)}.
# [INFO 12-30 05:57:44] ax.service.ax_client: Generated new trial 53 with parameters {'x0': 0.835109, 'x1': -0.300281, 'x2': 0.989598, 'x3': 0.542533, 'x4': 0.182619, 'x5': -1.907924, 'x6': 0.308957, 'x7': 0.123011, 'x8': 1.925488, 'x9': 0.555519} using model BoTorch.
# [INFO 12-30 05:57:44] ax.service.ax_client: Completed trial 53 with data: {'f8': (636106.699256, 0)}.
# [INFO 12-30 05:57:46] ax.service.ax_client: Generated new trial 54 with parameters {'x0': 0.053769, 'x1': -0.13973, 'x2': 0.9121, 'x3': 0.388898, 'x4': 0.643731, 'x5': -2.754002, 'x6': 0.206413, 'x7': 0.323597, 'x8': 1.768314, 'x9': 0.748176} using model BoTorch.
# [INFO 12-30 05:57:46] ax.service.ax_client: Completed trial 54 with data: {'f8': (797056.471951, 0)}.
# [INFO 12-30 05:57:48] ax.service.ax_client: Generated new trial 55 with parameters {'x0': 0.416924, 'x1': -0.291018, 'x2': 1.475705, 'x3': 0.586826, 'x4': 0.314645, 'x5': -1.342641, 'x6': 0.198434, 'x7': 0.927985, 'x8': 2.225374, 'x9': -0.078551} using model BoTorch.
# [INFO 12-30 05:57:48] ax.service.ax_client: Completed trial 55 with data: {'f8': (690705.400679, 0)}.
# [INFO 12-30 05:57:50] ax.service.ax_client: Generated new trial 56 with parameters {'x0': 0.775203, 'x1': -0.063434, 'x2': 1.363391, 'x3': 0.349857, 'x4': 0.374626, 'x5': -1.806701, 'x6': 0.350603, 'x7': 0.497428, 'x8': 1.303249, 'x9': 0.159382} using model BoTorch.
# [INFO 12-30 05:57:50] ax.service.ax_client: Completed trial 56 with data: {'f8': (493685.333664, 0)}.
# [INFO 12-30 05:57:52] ax.service.ax_client: Generated new trial 57 with parameters {'x0': 1.013907, 'x1': -0.088222, 'x2': 1.269474, 'x3': 0.432764, 'x4': 0.217973, 'x5': -1.92371, 'x6': -0.413194, 'x7': 1.352506, 'x8': 1.013607, 'x9': 0.173985} using model BoTorch.
# [INFO 12-30 05:57:52] ax.service.ax_client: Completed trial 57 with data: {'f8': (613572.339051, 0)}.
# [INFO 12-30 05:57:54] ax.service.ax_client: Generated new trial 58 with parameters {'x0': 0.820545, 'x1': -0.239792, 'x2': 1.099033, 'x3': 1.026892, 'x4': 0.737634, 'x5': -1.744393, 'x6': 0.573147, 'x7': 0.348771, 'x8': 0.905438, 'x9': 0.128894} using model BoTorch.
# [INFO 12-30 05:57:54] ax.service.ax_client: Completed trial 58 with data: {'f8': (486078.780562, 0)}.
# [INFO 12-30 05:57:57] ax.service.ax_client: Generated new trial 59 with parameters {'x0': 0.663355, 'x1': 0.276814, 'x2': 1.38213, 'x3': 0.825357, 'x4': 0.432146, 'x5': -1.637877, 'x6': 0.167751, 'x7': -0.016534, 'x8': 0.96584, 'x9': 0.050029} using model BoTorch.
# [INFO 12-30 05:57:57] ax.service.ax_client: Completed trial 59 with data: {'f8': (343900.458995, 0)}.
# [INFO 12-30 05:57:59] ax.service.ax_client: Generated new trial 60 with parameters {'x0': 0.445181, 'x1': 1.184541, 'x2': 1.516311, 'x3': 1.435707, 'x4': 0.254098, 'x5': -1.849123, 'x6': -0.112272, 'x7': -0.697381, 'x8': 0.864264, 'x9': -0.052835} using model BoTorch.
# [INFO 12-30 05:58:00] ax.service.ax_client: Completed trial 60 with data: {'f8': (737119.712128, 0)}.
# [INFO 12-30 05:58:02] ax.service.ax_client: Generated new trial 61 with parameters {'x0': 0.56534, 'x1': 0.32484, 'x2': 1.50947, 'x3': 1.253601, 'x4': 0.81629, 'x5': -1.446196, 'x6': -0.518972, 'x7': 0.163238, 'x8': 0.74304, 'x9': 0.715046} using model BoTorch.
# [INFO 12-30 05:58:02] ax.service.ax_client: Completed trial 61 with data: {'f8': (386414.995413, 0)}.
# [INFO 12-30 05:58:04] ax.service.ax_client: Generated new trial 62 with parameters {'x0': 0.513444, 'x1': 0.575602, 'x2': 1.250823, 'x3': 1.003635, 'x4': 1.138882, 'x5': -1.160909, 'x6': 0.131911, 'x7': 0.447921, 'x8': 0.865184, 'x9': -0.341969} using model BoTorch.
# [INFO 12-30 05:58:04] ax.service.ax_client: Completed trial 62 with data: {'f8': (405350.487846, 0)}.
# [INFO 12-30 05:58:07] ax.service.ax_client: Generated new trial 63 with parameters {'x0': 0.366522, 'x1': 0.147468, 'x2': 1.4521, 'x3': 1.308651, 'x4': 0.361745, 'x5': -1.658564, 'x6': -0.095736, 'x7': -0.172034, 'x8': 0.716559, 'x9': -0.328263} using model BoTorch.
# [INFO 12-30 05:58:07] ax.service.ax_client: Completed trial 63 with data: {'f8': (461009.119676, 0)}.
# [INFO 12-30 05:58:10] ax.service.ax_client: Generated new trial 64 with parameters {'x0': 1.032725, 'x1': 0.440724, 'x2': 1.365315, 'x3': 0.725363, 'x4': 0.720108, 'x5': -1.380204, 'x6': 0.096461, 'x7': -0.904382, 'x8': 0.741762, 'x9': 1.031738} using model BoTorch.
# [INFO 12-30 05:58:10] ax.service.ax_client: Completed trial 64 with data: {'f8': (388461.546781, 0)}.
# [INFO 12-30 05:58:12] ax.service.ax_client: Generated new trial 65 with parameters {'x0': 1.304608, 'x1': 0.426169, 'x2': 1.396792, 'x3': 1.019394, 'x4': 0.833023, 'x5': -1.515014, 'x6': -0.395807, 'x7': -0.157775, 'x8': 0.989031, 'x9': 0.45347} using model BoTorch.
# [INFO 12-30 05:58:12] ax.service.ax_client: Completed trial 65 with data: {'f8': (455620.710069, 0)}.
# [INFO 12-30 05:58:16] ax.service.ax_client: Generated new trial 66 with parameters {'x0': 0.452682, 'x1': 0.276048, 'x2': 1.396273, 'x3': 0.614263, 'x4': 0.783607, 'x5': -1.430006, 'x6': -0.426511, 'x7': -0.068884, 'x8': 0.82877, 'x9': 1.19486} using model BoTorch.
# [INFO 12-30 05:58:16] ax.service.ax_client: Completed trial 66 with data: {'f8': (327973.542366, 0)}.
# [INFO 12-30 05:58:21] ax.service.ax_client: Generated new trial 67 with parameters {'x0': 0.425536, 'x1': 0.36687, 'x2': 1.373764, 'x3': 0.65787, 'x4': 0.734176, 'x5': -1.403575, 'x6': 0.07711, 'x7': -0.181993, 'x8': 0.817929, 'x9': 0.505518} using model BoTorch.
# [INFO 12-30 05:58:21] ax.service.ax_client: Completed trial 67 with data: {'f8': (266693.742345, 0)}.
# [INFO 12-30 05:58:24] ax.service.ax_client: Generated new trial 68 with parameters {'x0': -0.186942, 'x1': 0.483447, 'x2': 1.355867, 'x3': 0.513227, 'x4': 0.983649, 'x5': -1.162063, 'x6': -0.41806, 'x7': -0.649328, 'x8': 0.861263, 'x9': -0.074366} using model BoTorch.
# [INFO 12-30 05:58:24] ax.service.ax_client: Completed trial 68 with data: {'f8': (399219.953441, 0)}.
# [INFO 12-30 05:58:27] ax.service.ax_client: Generated new trial 69 with parameters {'x0': 0.171074, 'x1': 0.632562, 'x2': 1.340239, 'x3': 0.427558, 'x4': 0.861075, 'x5': -1.337897, 'x6': 0.453216, 'x7': 0.002459, 'x8': 0.376941, 'x9': 0.648015} using model BoTorch.
# [INFO 12-30 05:58:27] ax.service.ax_client: Completed trial 69 with data: {'f8': (260220.209875, 0)}.
# [INFO 12-30 05:58:29] ax.service.ax_client: Generated new trial 70 with parameters {'x0': 2.797106, 'x1': -3.162278, 'x2': 1.35052, 'x3': 1.728673, 'x4': -1.483999, 'x5': -2.740595, 'x6': -0.387744, 'x7': -1.164201, 'x8': 2.219665, 'x9': -0.78651} using model BoTorch.
# [INFO 12-30 05:58:29] ax.service.ax_client: Completed trial 70 with data: {'f8': (1793353.17614, 0)}.
# [INFO 12-30 05:58:34] ax.service.ax_client: Generated new trial 71 with parameters {'x0': 0.342374, 'x1': 0.450053, 'x2': 1.373492, 'x3': 0.452665, 'x4': 0.924178, 'x5': -1.431188, 'x6': 0.298592, 'x7': -0.41891, 'x8': 0.225248, 'x9': 0.318558} using model BoTorch.
# [INFO 12-30 05:58:34] ax.service.ax_client: Completed trial 71 with data: {'f8': (320972.38437, 0)}.
# [INFO 12-30 05:58:37] ax.service.ax_client: Generated new trial 72 with parameters {'x0': 0.10045, 'x1': 0.620586, 'x2': 1.301254, 'x3': 0.574056, 'x4': 0.791558, 'x5': -1.125347, 'x6': 0.417437, 'x7': 0.047274, 'x8': 0.940519, 'x9': 0.879847} using model BoTorch.
# [INFO 12-30 05:58:37] ax.service.ax_client: Completed trial 72 with data: {'f8': (259933.763867, 0)}.
# [INFO 12-30 05:58:41] ax.service.ax_client: Generated new trial 73 with parameters {'x0': 0.205084, 'x1': 0.571909, 'x2': 1.063542, 'x3': 0.598702, 'x4': 0.800221, 'x5': -1.336304, 'x6': 0.242814, 'x7': 0.167326, 'x8': 0.632484, 'x9': 0.667966} using model BoTorch.
# [INFO 12-30 05:58:41] ax.service.ax_client: Completed trial 73 with data: {'f8': (215868.115639, 0)}.
# [INFO 12-30 05:58:44] ax.service.ax_client: Generated new trial 74 with parameters {'x0': 0.019674, 'x1': -2.823869, 'x2': 0.940188, 'x3': 0.485124, 'x4': 0.851344, 'x5': -2.31901, 'x6': 2.338545, 'x7': -1.214196, 'x8': 3.162278, 'x9': -1.719066} using model BoTorch.
# [INFO 12-30 05:58:44] ax.service.ax_client: Completed trial 74 with data: {'f8': (1822066.070508, 0)}.
# [INFO 12-30 05:58:47] ax.service.ax_client: Generated new trial 75 with parameters {'x0': -0.136321, 'x1': 0.638502, 'x2': 0.871225, 'x3': 0.801954, 'x4': 1.159971, 'x5': -1.596221, 'x6': 0.456854, 'x7': 0.084222, 'x8': 0.622971, 'x9': 0.884578} using model BoTorch.
# [INFO 12-30 05:58:47] ax.service.ax_client: Completed trial 75 with data: {'f8': (298261.733498, 0)}.
# [INFO 12-30 05:58:50] ax.service.ax_client: Generated new trial 76 with parameters {'x0': 0.326014, 'x1': 0.976284, 'x2': 0.982571, 'x3': 0.20799, 'x4': 0.969932, 'x5': -1.214374, 'x6': -0.347194, 'x7': 0.861819, 'x8': 0.646755, 'x9': 0.624355} using model BoTorch.
# [INFO 12-30 05:58:50] ax.service.ax_client: Completed trial 76 with data: {'f8': (409094.833221, 0)}.
# [INFO 12-30 05:58:56] ax.service.ax_client: Generated new trial 77 with parameters {'x0': 0.264845, 'x1': 0.474991, 'x2': 0.850305, 'x3': 0.685831, 'x4': 0.653805, 'x5': -1.285448, 'x6': 0.420658, 'x7': 0.125245, 'x8': 0.512594, 'x9': 0.766443} using model BoTorch.
# [INFO 12-30 05:58:56] ax.service.ax_client: Completed trial 77 with data: {'f8': (187285.20322, 0)}.
# [INFO 12-30 05:58:58] ax.service.ax_client: Generated new trial 78 with parameters {'x0': 0.305184, 'x1': -2.767663, 'x2': 2.932938, 'x3': 0.169537, 'x4': -1.466359, 'x5': -3.162278, 'x6': -3.162278, 'x7': 1.744717, 'x8': 3.162278, 'x9': -0.74904} using model BoTorch.
# [INFO 12-30 05:58:58] ax.service.ax_client: Completed trial 78 with data: {'f8': (2273427.30953, 0)}.
# [INFO 12-30 05:59:01] ax.service.ax_client: Generated new trial 79 with parameters {'x0': 0.716895, 'x1': 0.517208, 'x2': 0.532155, 'x3': 0.968323, 'x4': 0.798837, 'x5': -1.252104, 'x6': 0.741825, 'x7': 0.81146, 'x8': -0.008811, 'x9': 1.274988} using model BoTorch.
# [INFO 12-30 05:59:01] ax.service.ax_client: Completed trial 79 with data: {'f8': (310811.492697, 0)}.
# [INFO 12-30 05:59:04] ax.service.ax_client: Generated new trial 80 with parameters {'x0': 0.273249, 'x1': 0.466026, 'x2': 0.683608, 'x3': 0.647683, 'x4': 0.654546, 'x5': -0.990666, 'x6': 0.467365, 'x7': -0.12311, 'x8': 0.418369, 'x9': 0.604143} using model BoTorch.
# [INFO 12-30 05:59:04] ax.service.ax_client: Completed trial 80 with data: {'f8': (164677.852199, 0)}.
# [INFO 12-30 05:59:07] ax.service.ax_client: Generated new trial 81 with parameters {'x0': 2.160093, 'x1': -0.564354, 'x2': -2.916167, 'x3': 1.484367, 'x4': 1.934209, 'x5': -0.165532, 'x6': -0.435173, 'x7': -2.061115, 'x8': 0.155651, 'x9': 1.829314} using model BoTorch.
# [INFO 12-30 05:59:07] ax.service.ax_client: Completed trial 81 with data: {'f8': (1393366.419904, 0)}.
# [INFO 12-30 05:59:10] ax.service.ax_client: Generated new trial 82 with parameters {'x0': 0.366098, 'x1': 0.318348, 'x2': 0.702475, 'x3': 0.690091, 'x4': 0.541276, 'x5': -0.890349, 'x6': 0.220502, 'x7': -0.068314, 'x8': 0.304593, 'x9': 0.675543} using model BoTorch.
# [INFO 12-30 05:59:10] ax.service.ax_client: Completed trial 82 with data: {'f8': (135867.403091, 0)}.
# [INFO 12-30 05:59:13] ax.service.ax_client: Generated new trial 83 with parameters {'x0': 0.522532, 'x1': 0.01289, 'x2': 0.521617, 'x3': 0.598202, 'x4': 0.478059, 'x5': -0.860536, 'x6': 0.097025, 'x7': -0.187104, 'x8': 0.159201, 'x9': 0.795599} using model BoTorch.
# [INFO 12-30 05:59:13] ax.service.ax_client: Completed trial 83 with data: {'f8': (132041.348649, 0)}.
# [INFO 12-30 05:59:16] ax.service.ax_client: Generated new trial 84 with parameters {'x0': 1.038952, 'x1': 0.115563, 'x2': 0.565937, 'x3': 0.697977, 'x4': 0.262253, 'x5': -0.711862, 'x6': 0.020746, 'x7': -0.193146, 'x8': 0.177564, 'x9': 0.761281} using model BoTorch.
# [INFO 12-30 05:59:16] ax.service.ax_client: Completed trial 84 with data: {'f8': (147044.804568, 0)}.
# [INFO 12-30 05:59:18] ax.service.ax_client: Generated new trial 85 with parameters {'x0': -2.52565, 'x1': 0.058768, 'x2': 2.852765, 'x3': 0.265527, 'x4': -1.09105, 'x5': -2.547548, 'x6': 1.392969, 'x7': -0.766488, 'x8': 3.162278, 'x9': -0.277187} using model BoTorch.
# [INFO 12-30 05:59:18] ax.service.ax_client: Completed trial 85 with data: {'f8': (2155133.725285, 0)}.
# [INFO 12-30 05:59:21] ax.service.ax_client: Generated new trial 86 with parameters {'x0': 2.162063, 'x1': -1.228216, 'x2': 0.107962, 'x3': 0.188131, 'x4': 0.251677, 'x5': 0.923535, 'x6': -0.753243, 'x7': -2.173238, 'x8': 0.941245, 'x9': -0.70411} using model BoTorch.
# [INFO 12-30 05:59:21] ax.service.ax_client: Completed trial 86 with data: {'f8': (1265241.451248, 0)}.
# [INFO 12-30 05:59:24] ax.service.ax_client: Generated new trial 87 with parameters {'x0': -3.162278, 'x1': 2.714297, 'x2': 1.732217, 'x3': -0.053875, 'x4': 3.162278, 'x5': -2.846506, 'x6': 2.130546, 'x7': 2.573099, 'x8': 3.041719, 'x9': -1.434921} using model BoTorch.
# [INFO 12-30 05:59:24] ax.service.ax_client: Completed trial 87 with data: {'f8': (2460501.382195, 0)}.
# [INFO 12-30 05:59:27] ax.service.ax_client: Generated new trial 88 with parameters {'x0': 3.162278, 'x1': -2.71466, 'x2': -3.162278, 'x3': 3.162278, 'x4': 1.543864, 'x5': -1.43766, 'x6': -1.800968, 'x7': -0.739822, 'x8': 3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 05:59:27] ax.service.ax_client: Completed trial 88 with data: {'f8': (2525920.670105, 0)}.
# [INFO 12-30 05:59:30] ax.service.ax_client: Generated new trial 89 with parameters {'x0': -0.031024, 'x1': -2.834038, 'x2': -3.162278, 'x3': 0.309959, 'x4': 0.730522, 'x5': -1.52663, 'x6': -1.879129, 'x7': -2.094144, 'x8': -0.604325, 'x9': -0.809623} using model BoTorch.
# [INFO 12-30 05:59:30] ax.service.ax_client: Completed trial 89 with data: {'f8': (1682630.339572, 0)}.
# ...
# [INFO 12-30 08:17:35] ax.service.ax_client: Completed trial 337 with data: {'f8': (3006343.491863, 0)}.
# [INFO 12-30 08:17:51] ax.service.ax_client: Generated new trial 338 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': -3.162278, 'x5': 3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:17:51] ax.service.ax_client: Completed trial 338 with data: {'f8': (2916593.799321, 0)}.
# [INFO 12-30 08:18:06] ax.service.ax_client: Generated new trial 339 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': -3.162278, 'x4': -3.162278, 'x5': 3.162278, 'x6': 3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:18:06] ax.service.ax_client: Completed trial 339 with data: {'f8': (5094010.947534, 0)}.
# [INFO 12-30 08:18:21] ax.service.ax_client: Generated new trial 340 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': -3.162278, 'x3': 3.162278, 'x4': -0.098744, 'x5': -3.162278, 'x6': -3.162278, 'x7': 3.162278, 'x8': 3.162278, 'x9': -3.162278} using model BoTorch.
# [INFO 12-30 08:18:21] ax.service.ax_client: Completed trial 340 with data: {'f8': (2623374.617366, 0)}.
# [INFO 12-30 08:18:37] ax.service.ax_client: Generated new trial 341 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': -3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': 3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:18:37] ax.service.ax_client: Completed trial 341 with data: {'f8': (3732930.805587, 0)}.
# [INFO 12-30 08:18:53] ax.service.ax_client: Generated new trial 342 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': -3.162278, 'x3': 3.162278, 'x4': -3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:18:53] ax.service.ax_client: Completed trial 342 with data: {'f8': (3924595.38761, 0)}.
# [INFO 12-30 08:19:09] ax.service.ax_client: Generated new trial 343 with parameters {'x0': 3.162278, 'x1': -3.162278, 'x2': 3.162278, 'x3': -3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': 3.162278, 'x8': -3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:19:09] ax.service.ax_client: Completed trial 343 with data: {'f8': (3913210.904971, 0)}.
# [INFO 12-30 08:19:24] ax.service.ax_client: Generated new trial 344 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': -3.162278, 'x5': 3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': -3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:19:24] ax.service.ax_client: Completed trial 344 with data: {'f8': (3552408.798345, 0)}.
# [INFO 12-30 08:19:40] ax.service.ax_client: Generated new trial 345 with parameters {'x0': -3.162278, 'x1': -3.162278, 'x2': -3.162278, 'x3': -3.162278, 'x4': -3.162278, 'x5': 3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': -1.064416, 'x9': -3.162278} using model BoTorch.
# [INFO 12-30 08:19:40] ax.service.ax_client: Completed trial 345 with data: {'f8': (4551130.221336, 0)}.
# [INFO 12-30 08:19:56] ax.service.ax_client: Generated new trial 346 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': -3.162278, 'x3': -3.162278, 'x4': 3.162278, 'x5': 3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': -3.162278, 'x9': -3.162278} using model BoTorch.
# [INFO 12-30 08:19:56] ax.service.ax_client: Completed trial 346 with data: {'f8': (3500665.187982, 0)}.
# [INFO 12-30 08:20:12] ax.service.ax_client: Generated new trial 347 with parameters {'x0': 3.162278, 'x1': 0.063847, 'x2': -3.162278, 'x3': -3.162278, 'x4': 3.162278, 'x5': 3.162278, 'x6': -3.162278, 'x7': 3.162278, 'x8': 3.162278, 'x9': -2.095666} using model BoTorch.
# [INFO 12-30 08:20:12] ax.service.ax_client: Completed trial 347 with data: {'f8': (2445238.285285, 0)}.
# [INFO 12-30 08:20:29] ax.service.ax_client: Generated new trial 348 with parameters {'x0': 0.264501, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': 3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:20:29] ax.service.ax_client: Completed trial 348 with data: {'f8': (3311156.376019, 0)}.
# [INFO 12-30 08:20:45] ax.service.ax_client: Generated new trial 349 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': -0.67102, 'x3': -3.162278, 'x4': -0.785944, 'x5': 3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': -1.809241} using model BoTorch.
# [INFO 12-30 08:20:45] ax.service.ax_client: Completed trial 349 with data: {'f8': (2593883.303373, 0)}.
# [INFO 12-30 08:21:02] ax.service.ax_client: Generated new trial 350 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': -3.162278, 'x5': 0.884309, 'x6': -3.162278, 'x7': 3.162278, 'x8': 3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:21:02] ax.service.ax_client: Completed trial 350 with data: {'f8': (3516431.912211, 0)}.
# [INFO 12-30 08:21:18] ax.service.ax_client: Generated new trial 351 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': -3.162278, 'x4': -3.162278, 'x5': 0.325633, 'x6': -3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': -1.108768} using model BoTorch.
# [INFO 12-30 08:21:18] ax.service.ax_client: Completed trial 351 with data: {'f8': (3393398.745696, 0)}.
# [INFO 12-30 08:21:35] ax.service.ax_client: Generated new trial 352 with parameters {'x0': 0.517979, 'x1': 3.162278, 'x2': 3.162278, 'x3': -3.162278, 'x4': -3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:21:35] ax.service.ax_client: Completed trial 352 with data: {'f8': (4082467.636818, 0)}.
# [INFO 12-30 08:21:52] ax.service.ax_client: Generated new trial 353 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': -3.162278, 'x3': 3.162278, 'x4': -1.829062, 'x5': 3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': -3.162278, 'x9': -3.162278} using model BoTorch.
# [INFO 12-30 08:21:52] ax.service.ax_client: Completed trial 353 with data: {'f8': (3677472.303477, 0)}.
# [INFO 12-30 08:22:09] ax.service.ax_client: Generated new trial 354 with parameters {'x0': 3.162278, 'x1': -3.162278, 'x2': 3.162278, 'x3': -3.162278, 'x4': 3.162278, 'x5': 3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': -2.10074} using model BoTorch.
# [INFO 12-30 08:22:09] ax.service.ax_client: Completed trial 354 with data: {'f8': (3652908.320079, 0)}.
# [INFO 12-30 08:22:26] ax.service.ax_client: Generated new trial 355 with parameters {'x0': -1.25811, 'x1': 3.162278, 'x2': -3.162278, 'x3': -0.516542, 'x4': -3.162278, 'x5': 0.699258, 'x6': -3.162278, 'x7': -3.039414, 'x8': -0.91512, 'x9': 0.247784} using model BoTorch.
# [INFO 12-30 08:22:26] ax.service.ax_client: Completed trial 355 with data: {'f8': (3794490.17088, 0)}.
# [INFO 12-30 08:22:43] ax.service.ax_client: Generated new trial 356 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': -3.162278, 'x4': 3.162278, 'x5': 1.181485, 'x6': -3.162278, 'x7': 3.162278, 'x8': 3.162278, 'x9': -3.162278} using model BoTorch.
# [INFO 12-30 08:22:43] ax.service.ax_client: Completed trial 356 with data: {'f8': (2818144.635882, 0)}.
# [INFO 12-30 08:23:00] ax.service.ax_client: Generated new trial 357 with parameters {'x0': -3.162278, 'x1': -3.162278, 'x2': 3.162278, 'x3': -3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': 3.162278, 'x8': 3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:23:00] ax.service.ax_client: Completed trial 357 with data: {'f8': (3781638.339294, 0)}.
# [INFO 12-30 08:23:17] ax.service.ax_client: Generated new trial 358 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': -3.162278, 'x3': -3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': -1.261966, 'x9': -3.162278} using model BoTorch.
# [INFO 12-30 08:23:17] ax.service.ax_client: Completed trial 358 with data: {'f8': (3007337.180732, 0)}.
# [INFO 12-30 08:23:34] ax.service.ax_client: Generated new trial 359 with parameters {'x0': -3.162278, 'x1': -3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': -3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': -3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:23:34] ax.service.ax_client: Completed trial 359 with data: {'f8': (3859046.811385, 0)}.
# [INFO 12-30 08:23:51] ax.service.ax_client: Generated new trial 360 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': -3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': -3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:23:51] ax.service.ax_client: Completed trial 360 with data: {'f8': (3591922.115367, 0)}.
# [INFO 12-30 08:24:08] ax.service.ax_client: Generated new trial 361 with parameters {'x0': 3.162278, 'x1': -3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': 3.162278, 'x6': -3.162278, 'x7': 3.162278, 'x8': -3.162278, 'x9': -0.927471} using model BoTorch.
# [INFO 12-30 08:24:08] ax.service.ax_client: Completed trial 361 with data: {'f8': (2842856.014787, 0)}.
# [INFO 12-30 08:24:25] ax.service.ax_client: Generated new trial 362 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': 3.162278, 'x7': 3.162278, 'x8': -3.162278, 'x9': -3.162278} using model BoTorch.
# [INFO 12-30 08:24:25] ax.service.ax_client: Completed trial 362 with data: {'f8': (3163706.155748, 0)}.
# [INFO 12-30 08:24:43] ax.service.ax_client: Generated new trial 363 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': -3.162278, 'x3': -0.01247, 'x4': -3.162278, 'x5': 3.162278, 'x6': -3.162278, 'x7': 1.414029, 'x8': 3.162278, 'x9': -1.9526} using model BoTorch.
# [INFO 12-30 08:24:43] ax.service.ax_client: Completed trial 363 with data: {'f8': (2463372.087971, 0)}.
# [INFO 12-30 08:25:00] ax.service.ax_client: Generated new trial 364 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': -0.728657} using model BoTorch.
# [INFO 12-30 08:25:00] ax.service.ax_client: Completed trial 364 with data: {'f8': (1567638.637313, 0)}.
# [INFO 12-30 08:25:18] ax.service.ax_client: Generated new trial 365 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': -3.162278, 'x3': 3.162278, 'x4': -3.162278, 'x5': -3.162278, 'x6': 3.162278, 'x7': 3.162278, 'x8': 3.162278, 'x9': 1.038315} using model BoTorch.
# [INFO 12-30 08:25:18] ax.service.ax_client: Completed trial 365 with data: {'f8': (4609483.06999, 0)}.
# [INFO 12-30 08:25:35] ax.service.ax_client: Generated new trial 366 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': -3.162278, 'x5': -3.162278, 'x6': 3.162278, 'x7': -3.162278, 'x8': -3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:25:35] ax.service.ax_client: Completed trial 366 with data: {'f8': (4289866.336842, 0)}.
# [INFO 12-30 08:25:53] ax.service.ax_client: Generated new trial 367 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': -0.263543, 'x3': 3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': 1.847673, 'x8': 3.162278, 'x9': 0.233754} using model BoTorch.
# [INFO 12-30 08:25:53] ax.service.ax_client: Completed trial 367 with data: {'f8': (1653764.916084, 0)}.
# [INFO 12-30 08:26:11] ax.service.ax_client: Generated new trial 368 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': 0.450552, 'x6': -3.162278, 'x7': -3.162278, 'x8': -3.162278, 'x9': 0.720741} using model BoTorch.
# [INFO 12-30 08:26:11] ax.service.ax_client: Completed trial 368 with data: {'f8': (3659561.173684, 0)}.
# [INFO 12-30 08:26:29] ax.service.ax_client: Generated new trial 369 with parameters {'x0': -3.162278, 'x1': 0.629511, 'x2': 3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': 0.143219, 'x7': 3.162278, 'x8': 3.162278, 'x9': 0.550193} using model BoTorch.
# [INFO 12-30 08:26:29] ax.service.ax_client: Completed trial 369 with data: {'f8': (1740937.388039, 0)}.
# [INFO 12-30 08:26:46] ax.service.ax_client: Generated new trial 370 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': -3.162278, 'x5': -3.162278, 'x6': 3.162278, 'x7': -3.162278, 'x8': 3.162278, 'x9': -3.162278} using model BoTorch.
# [INFO 12-30 08:26:46] ax.service.ax_client: Completed trial 370 with data: {'f8': (2869351.557653, 0)}.
# [INFO 12-30 08:27:04] ax.service.ax_client: Generated new trial 371 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': -3.162278, 'x3': -3.162278, 'x4': -3.162278, 'x5': -3.162278, 'x6': 3.162278, 'x7': -3.162278, 'x8': -3.162278, 'x9': -3.162278} using model BoTorch.
# [INFO 12-30 08:27:04] ax.service.ax_client: Completed trial 371 with data: {'f8': (4358601.885788, 0)}.
# [INFO 12-30 08:27:22] ax.service.ax_client: Generated new trial 372 with parameters {'x0': 3.162278, 'x1': -3.162278, 'x2': -0.161091, 'x3': 3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': 3.162278, 'x8': 3.162278, 'x9': 0.152862} using model BoTorch.
# [INFO 12-30 08:27:22] ax.service.ax_client: Completed trial 372 with data: {'f8': (1651645.830535, 0)}.
# [INFO 12-30 08:27:40] ax.service.ax_client: Generated new trial 373 with parameters {'x0': 0.290276, 'x1': 0.618251, 'x2': 1.074269, 'x3': 3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': 3.162278, 'x8': 3.162278, 'x9': 0.830606} using model BoTorch.
# [INFO 12-30 08:27:40] ax.service.ax_client: Completed trial 373 with data: {'f8': (1558801.313731, 0)}.
# [INFO 12-30 08:27:59] ax.service.ax_client: Generated new trial 374 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': 3.162278, 'x8': -3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:27:59] ax.service.ax_client: Completed trial 374 with data: {'f8': (2476822.38614, 0)}.
# [INFO 12-30 08:28:19] ax.service.ax_client: Generated new trial 375 with parameters {'x0': -3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 0.687878, 'x4': 0.060477, 'x5': -3.162278, 'x6': 0.768033, 'x7': -3.162278, 'x8': 3.162278, 'x9': 0.139903} using model BoTorch.
# [INFO 12-30 08:28:19] ax.service.ax_client: Completed trial 375 with data: {'f8': (2215954.568597, 0)}.
# [INFO 12-30 08:28:40] ax.service.ax_client: Generated new trial 376 with parameters {'x0': 1.621804, 'x1': -3.162278, 'x2': 3.162278, 'x3': -3.162278, 'x4': 3.162278, 'x5': -3.162278, 'x6': -3.162278, 'x7': 3.162278, 'x8': -3.162278, 'x9': -2.26371} using model BoTorch.
# [INFO 12-30 08:28:40] ax.service.ax_client: Completed trial 376 with data: {'f8': (2452804.318232, 0)}.
# [INFO 12-30 08:29:00] ax.service.ax_client: Generated new trial 377 with parameters {'x0': 3.162278, 'x1': -3.162278, 'x2': 3.162278, 'x3': -1.655641, 'x4': -2.716615, 'x5': -3.162278, 'x6': -3.162278, 'x7': 3.162278, 'x8': 3.162278, 'x9': 1.376927} using model BoTorch.
# [INFO 12-30 08:29:00] ax.service.ax_client: Completed trial 377 with data: {'f8': (2785891.716838, 0)}.
# [INFO 12-30 08:29:21] ax.service.ax_client: Generated new trial 378 with parameters {'x0': -3.162278, 'x1': 0.612793, 'x2': 3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': -0.206548, 'x6': -3.162278, 'x7': 3.162278, 'x8': 3.162278, 'x9': 0.471101} using model BoTorch.
# [INFO 12-30 08:29:21] ax.service.ax_client: Completed trial 378 with data: {'f8': (1989329.654509, 0)}.
# [INFO 12-30 08:29:39] ax.service.ax_client: Generated new trial 379 with parameters {'x0': 3.162278, 'x1': 3.162278, 'x2': 3.162278, 'x3': 3.162278, 'x4': 3.162278, 'x5': 3.162278, 'x6': 3.162278, 'x7': 3.162278, 'x8': -3.162278, 'x9': 3.162278} using model BoTorch.
# [INFO 12-30 08:29:39] ax.service.ax_client: Completed trial 379 with data: {'f8': (3967650.975853, 0)}.
